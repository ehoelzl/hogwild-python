# %% [markdown]
# # Run notebook from hogwild-python environnement

# %%
! echo $CONDA_PREFIX
# Out:
# /Users/Romain/anaconda/envs/hogwild-python

# %%
! pwd
# Out:
# /Users/Romain/Documents/EPFL/Systems/hogwild-python

# %%
PROJECT__LOGS_PATH = "/Users/Romain/Documents/EPFL/Systems/Project/Notebooks/logs"

# %%
! cd src/hogwild & python -m grpc_tools.protoc -I. --python_out=. --grpc_python_out=. hogwild.proto
# Out:
# /Users/Romain/anaconda/bin/python: Error while finding module specification for 'grpc_tools.protoc' (ModuleNotFoundError: No module named 'grpc_tools')

# %%
max_workers = 10

# %%
# Synchronous 
for num_workers in range(1, max_workers + 1):
    ! bash run.sh -n {num_workers} -r synchronous -w cluster
# Out:
# ----- Deleting remaining infra -----
# Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?
# Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?
#
# ----- Starting workers -----
# configmap/hogwild-config created
# service/workers-service created
# statefulset.apps/worker created
#
#
# ----- Workers are up and running, starting coordinator -----
# service/coordinator-service created
# statefulset.apps/coordinator created
#
# ----- Running Job -----
# tar: log.json: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
# tar: log.json: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
# tar: log.json: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
# tar: log.json: Cannot stat: No such file or directory
# ...

# %%
# Asynchronous 
for num_workers in range(1, 11):
    ! bash run.sh -n {num_workers} -r asynchronous -w cluster
# Out:
# ----- Deleting remaining infra -----
# ^C
#
#
# ----- Deleting remaining infra -----
# ^C
#
#
# ----- Deleting remaining infra -----
# ^C
# ^C
#
#
# ----- Deleting remaining infra -----
# ^C
#
#
# ----- Deleting remaining infra -----
# ^C
#
#
# ----- Deleting remaining infra -----
# service "workers-service" deleted
# statefulset.apps "worker" deleted
# ^C
#
#
# ----- Deleting remaining infra -----
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     155             else:
# --> 156                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     157             flush = sys.stdout.flush
#
# ...

# %%
! cp -r logs {PROJECT__LOGS_PATH}
